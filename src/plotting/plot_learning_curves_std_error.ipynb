# %%
import matplotlib.pyplot as plt
from collections import defaultdict
from pathlib import Path
import numpy as np
import pickle
import yaml

plt.rcParams.update({'font.size': 16})

def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w

plotting_dir = Path().resolve()
config_dir = plotting_dir / "ppo_config.yaml"
print(config_dir)

with open(config_dir, "r") as file:
    config = yaml.safe_load(file)
    print(config)
    

fig = plt.figure(figsize=(12, 7))
ax = fig.add_subplot(111)

# Store data by experiment group
experiment_data = defaultdict(list)
max_len = 0

# First pass: collect data for each experiment
for batch in config["batches"]:
    for experiment in config["experiments"]:
        exp_key = f"{batch}-{experiment}"
        
        for trial in config["trials"]:
            checkpoint_path = Path(f"{config['base_path']}/{batch}/{experiment}/{trial}/logs/train.dat")
            print(checkpoint_path)
            

            if checkpoint_path.is_file():
                with open(checkpoint_path, "rb") as handle:
                    data = pickle.load(handle)
                    data = data["rewards_per_iteration"][:config["datapoints"][0]]
                    # data = data["rewards_per_episode"][:config["datapoints"][0]]
                    
                    # Apply moving average
                    if len(data) > config["moving_avg_window_size"]:
                        smoothed_data = moving_average(data, config["moving_avg_window_size"])
                        experiment_data[exp_key].append(smoothed_data)
                        max_len = max(max_len, len(smoothed_data))
                    else:
                        print(f"Warning: Trial {trial} has too few data points for smoothing")

# Second pass: pad arrays to the same length if needed
for exp_key in experiment_data:
    padded_data = []
    for trial_data in experiment_data[exp_key]:
        if len(trial_data) < max_len:
            # Pad with last value or NaN
            padding = np.full(max_len - len(trial_data), np.nan)
            padded_data.append(np.concatenate([trial_data, padding]))
        else:
            padded_data.append(trial_data)
    
    experiment_data[exp_key] = padded_data

# Plotting with standard error
color_idx = 0
for exp_key in experiment_data:
    if not experiment_data[exp_key]:
        print(f"No data for {exp_key}")
        continue
        
    # Convert list of arrays to 2D numpy array
    data_array = np.array(experiment_data[exp_key])
    
    # Calculate mean and standard error across trials
    mean_rewards = np.nanmean(data_array, axis=0)
    
    # Standard Error = StdDev / sqrt(n)
    n_trials = np.sum(~np.isnan(data_array), axis=0)  # Count non-NaN values at each step
    std_rewards = np.nanstd(data_array, axis=0)
    se_rewards = std_rewards / np.sqrt(np.maximum(n_trials, 1))  # Avoid division by zero
    
    # X axis
    x = np.arange(len(mean_rewards))
    
    # Get color for this experiment
    color = plt.cm.tab10(color_idx % 10)
    color_idx += 1
    
    # Plot mean line
    ax.plot(x, mean_rewards, linewidth=1, label=exp_key, color=color)
    
    # Plot standard error band
    ax.fill_between(
        x,
        mean_rewards - se_rewards,
        mean_rewards + se_rewards,
        alpha=0.3,
        color=color
    )
    
    print(f"{exp_key}: {len(experiment_data[exp_key])} trials")

ax.legend(loc='best')
ax.set_xlabel("Iterations")
ax.set_ylabel("Average Reward")
ax.set_title("Learning Curves with Standard Error Across Trials")
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# /home/sophie/scalable-salp-locomotion/src/plotting/ppo_config.yaml
# {'moving_avg_window_size': 200, 'datapoints': [30000, 30000], 'base_path': '/home/sophie/scalable-salp-locomotion/src/experiments/results', 'batches': ['salp_navigate_5a'], 'experiments': ['mlp', 'gcn', 'gat', 'graph_transformer', 'gcn_full', 'gat_full', 'graph_transformer_full'], 'trials': ['0', '1', '2', '3', '4']}
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/mlp/0/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/mlp/1/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/mlp/2/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/mlp/3/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/mlp/4/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/gcn/0/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/gcn/1/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/gcn/2/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/gcn/3/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/gcn/4/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/gat/0/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/gat/1/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/gat/2/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/gat/3/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/gat/4/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/graph_transformer/0/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/graph_transformer/1/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/graph_transformer/2/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/graph_transformer/3/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/graph_transformer/4/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/gcn_full/0/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/gcn_full/1/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/gcn_full/2/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/gcn_full/3/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/gcn_full/4/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/gat_full/0/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/gat_full/1/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/gat_full/2/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/gat_full/3/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/gat_full/4/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/graph_transformer_full/0/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/graph_transformer_full/1/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/graph_transformer_full/2/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/graph_transformer_full/3/logs/train.dat
# /home/sophie/scalable-salp-locomotion/src/experiments/results/salp_navigate_5a/graph_transformer_full/4/logs/train.dat
# salp_navigate_5a-mlp: 1 trials
# salp_navigate_5a-gcn: 1 trials
# /tmp/ipykernel_11693/700842829.py:77: RuntimeWarning: Mean of empty slice
#   mean_rewards = np.nanmean(data_array, axis=0)
